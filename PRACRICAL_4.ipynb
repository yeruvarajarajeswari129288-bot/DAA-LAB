# %%
import time

n = int(input("Enter a number: "))

start_time = time.perf_counter()

fact = 1
for i in range(1, n + 1):
    fact = fact * i

end_time = time.perf_counter()

execution_time = end_time - start_time

print("Factorial =", fact)
print("Execution Time =", execution_time, "seconds")
print("Time Complexity = O(n)")
# Out:
# Enter a number: 7
# Factorial = 5040
# Execution Time = 0.00016588899984526506 seconds
# Time Complexity = O(n)

# %%
import time

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)


n = int(input("Enter a number: "))

start_time = time.perf_counter()

fact = factorial(n)

end_time = time.perf_counter()

execution_time = end_time - start_time

print("Factorial =", fact)
print("Execution Time =", execution_time, "seconds")
print("Time Complexity = O(n)")
# Out:
# Enter a number: 10
# Factorial = 3628800
# Execution Time = 9.136099993156677e-05 seconds
# Time Complexity = O(n)
